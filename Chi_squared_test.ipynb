# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorekubendiran/numpy_task-Hypothesis-Chi-square-test-/blob/main/Chi_squared_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot_20221130_181811.png](data:image/png;base64,...)

# %%
rom scipy.stats import chi2_contingency
  
# defining the table
Data = [[141, 68, 4], [179, 159, 7], [220,216,4], [86,101,4]]
Calculated_ChiSq, p,  Degrees_of_Freedom, Expected_Values = chi2_contingency(Data)
  
# interpret p-value
Alpha = 0.05
print("p value is " + str(p))
if p >= Alpha:
    print('Independent (H0 Holds True / We accept the Null Hypothesis)') #No Co-relation
else:
    print('Dependent (We Reject the H0)') #Co-relation exists
